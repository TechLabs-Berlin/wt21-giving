# %%
#Data set from Charity Navigator

# %%
import pandas as pd
import numpy as np

# %%
#import data 

df_charity_data=pd.read_csv("charity_data.csv")

# %%
df_charity_data.head()
# Out:
#    ascore                   category  \
# 0   100.0                Environment
# 1    89.0  Arts, Culture, Humanities
# 2    70.0                   Religion
# 3    93.0  Arts, Culture, Humanities
# 4   100.0             Human Services
#
#                                          description         ein     tot_exp  \
# 0  Working with Oregonians to enhance our quality...  93-0642086    917313.0
# 1  Serving the metropolitan Baltimore area and th...  31-1770828   5053059.0
# 2  VSS Catholic Communications is dedicated to an...  91-1857425   1891500.0
# 3  The mission of the Utah Symphony & Opera is to...  51-0145980  22506582.0
# 4  Funded solely by the footwear industry, Two Te...  22-2579809   5594243.0
#
#    admin_exp_p  fund_eff  fund_exp_p  program_exp_p  fscore  ...  \
# 0        0.101      0.18       0.184          0.714   88.61  ...
# 1        0.231      0.05       0.032          0.735   82.85  ...
# 2        0.114      0.17       0.197          0.687   86.74  ...
# ...

# %%
df_charity_data.shape
# Out:
# (8408, 23)

# %%
schema_charity_data=pd.read_csv("charity_data.csv")

# %%
schema_charity_data
# Out:
#       ascore                   category  \
# 0      100.0                Environment
# 1       89.0  Arts, Culture, Humanities
# 2       70.0                   Religion
# 3       93.0  Arts, Culture, Humanities
# 4      100.0             Human Services
# ...      ...                        ...
# 8403    92.0  Arts, Culture, Humanities
# 8404    59.0                   Religion
# 8405   100.0             Human Services
# 8406   100.0             Human Services
# 8407   100.0  Arts, Culture, Humanities
#
#                                             description         ein  \
# 0     Working with Oregonians to enhance our quality...  93-0642086
# 1     Serving the metropolitan Baltimore area and th...  31-1770828
# 2     VSS Catholic Communications is dedicated to an...  91-1857425
# 3     The mission of the Utah Symphony & Opera is to...  51-0145980
# 4     Funded solely by the footwear industry, Two Te...  22-2579809
# ...

# %%
charity_data.columns
# Out:
# Index(['Name', 'Score', 'Category', 'Subcategory', 'Description', 'Motto'], dtype='object')

# %%
#List acording to the info I consider useful for the website

# %%
list_charity=["Name", "Score", "Category", "Subcategory", "Description", "Motto","Ranking", "fscore", "size"]

# %%
list_charity
# Out:
# ['Name',
#  'Score',
#  'Category',
#  'Subcategory',
#  'Description',
#  'Motto',
#  'Ranking',
#  'fscore',
#  'size']

# %%
df_charity_data.info
# Out:
# <bound method DataFrame.info of       ascore                   category  \
# 0      100.0                Environment
# 1       89.0  Arts, Culture, Humanities
# 2       70.0                   Religion
# 3       93.0  Arts, Culture, Humanities
# 4      100.0             Human Services
# ...      ...                        ...
# 8403    92.0  Arts, Culture, Humanities
# 8404    59.0                   Religion
# 8405   100.0             Human Services
# 8406   100.0             Human Services
# 8407   100.0  Arts, Culture, Humanities
#
#                                             description         ein  \
# 0     Working with Oregonians to enhance our quality...  93-0642086
# 1     Serving the metropolitan Baltimore area and th...  31-1770828
# 2     VSS Catholic Communications is dedicated to an...  91-1857425
# 3     The mission of the Utah Symphony & Opera is to...  51-0145980
# 4     Funded solely by the footwear industry, Two Te...  22-2579809
# ...

# %%
df_charity_data.loc[[0,1,2,3,4], "ascore"]
# Out:
# 0    100.0
# 1     89.0
# 2     70.0
# 3     93.0
# 4    100.0
# Name: ascore, dtype: float64

# %%
#Visualize colunns I find useful to work in

df_charity_data["name"]
# Out:
# 0                                  1000 Friends of Oregon
# 1                                                    WYPR
# 2                             VSS Catholic Communications
# 3                                   Utah Symphony & Opera
# 4                             Two Ten Footwear Foundation
#                               ...
# 8403                                                Yaddo
# 8404                             Yad L'Achim Peyle Israel
# 8405                                             Yad Ezra
# 8406                                              Rawhide
# 8407    The Raymond F. Kravis Center for the Performin...
# Name: name, Length: 8408, dtype: object

# %%
df_charity_data.loc[0:50, "description":"score"]
# Out:
#                                           description         ein  \
# 0   Working with Oregonians to enhance our quality...  93-0642086
# 1   Serving the metropolitan Baltimore area and th...  31-1770828
# 2   VSS Catholic Communications is dedicated to an...  91-1857425
# 3   The mission of the Utah Symphony & Opera is to...  51-0145980
# 4   Funded solely by the footwear industry, Two Te...  22-2579809
# 5   Syracuse Stage is a global village square wher...  15-0623468
# 6   Partnering with God in leading people to share...  95-6006642
# 7   Put On The B.R.A.K.E.S. (Be Responsible And Ke...  26-2176362
# 8   Ozarks Food Harvest has a mission of Transform...  43-1426384
# 9   NYC Outward Bound Schools transforms schools a...  13-3471084
# 10  Mystic Seaport was originally established as t...  06-0653120
# 11  The mission of the Lyric Theatre is to produce...  73-1001687
# 12  The mission of KVIE is to educate, enrich, enl...  94-1421463
# ...

# %%
#Columns info that we really want to work 
df_charity_data[["name","score","category","subcategory","description","motto","state","fscore","size"]]
# Out:
#                                                    name  score  \
# 0                                1000 Friends of Oregon  91.94
# 1                                                  WYPR  85.59
# 2                           VSS Catholic Communications  76.80
# 3                                 Utah Symphony & Opera  91.95
# 4                           Two Ten Footwear Foundation  90.26
# ...                                                 ...    ...
# 8403                                              Yaddo  79.36
# 8404                           Yad L'Achim Peyle Israel  59.84
# 8405                                           Yad Ezra  88.07
# 8406                                            Rawhide  96.91
# 8407  The Raymond F. Kravis Center for the Performin...  92.29
#
#                        category  \
# 0                   Environment
# 1     Arts, Culture, Humanities
# 2                      Religion
# 3     Arts, Culture, Humanities
# 4                Human Services
# ...

# %%
#Score filter. We want to keep charities with score higher than 85
df_charity_data[df_charity_data ["score"] >=85]
# Out:
#       ascore                   category  \
# 0      100.0                Environment
# 1       89.0  Arts, Culture, Humanities
# 3       93.0  Arts, Culture, Humanities
# 4      100.0             Human Services
# 7       81.0                  Education
# ...      ...                        ...
# 8401    96.0             Human Services
# 8402    89.0              International
# 8405   100.0             Human Services
# 8406   100.0             Human Services
# 8407   100.0  Arts, Culture, Humanities
#
#                                             description         ein  \
# 0     Working with Oregonians to enhance our quality...  93-0642086
# 1     Serving the metropolitan Baltimore area and th...  31-1770828
# 3     The mission of the Utah Symphony & Opera is to...  51-0145980
# 4     Funded solely by the footwear industry, Two Te...  22-2579809
# 7     Put On The B.R.A.K.E.S. (Be Responsible And Ke...  26-2176362
# ...

# %%
#Filter of score and category
cond1=df_charity_data["category"]=="Animals"
cond2=df_charity_data["score"]>=85

# %%
df_charity_data[cond1 & cond2]
# Out:
#       ascore category                                        description  \
# 15      89.0  Animals  ZooTampa at Lowry Park inspires guests to take...
# 16      93.0  Animals  The mission of the Zoological Society of Milwa...
# 17      85.0  Animals  The Point Defiance Zoological Society connects...
# 18      97.0  Animals  Zoo New England's mission is to inspire people...
# 19     100.0  Animals  Zoo Miami Foundation (ZMF) is the non-profit s...
# ...      ...      ...                                                ...
# 8149    85.0  Animals  The Hawaiian Humane Society's has been serving...
# 8207   100.0  Animals  Founded in 1937, Halifax Humane Society serves...
# 8291   100.0  Animals  The purpose of Habitat for Horses Inc. is a) T...
# 8295    97.0  Animals  The Xerces Society is a nonprofit organization...
# 8399    92.0  Animals  Yavapai Humane Society's mission is to promote...
#
#              ein     tot_exp  admin_exp_p  fund_eff  fund_exp_p  \
# ...

# %%
#Eliminating columns
columns_inter= ["ascore","ein","tot_exp","admin_exp_p","fund_eff","fund_exp_p","program_exp_p","leader","leader_comp","leader_comp_p","tot_rev","program_exp","fund_exp","admin_exp"]
df_charity_data.drop(columns=columns_inter)
# Out:
#                        category  \
# 0                   Environment
# 1     Arts, Culture, Humanities
# 2                      Religion
# 3     Arts, Culture, Humanities
# 4                Human Services
# ...                         ...
# 8403  Arts, Culture, Humanities
# 8404                   Religion
# 8405             Human Services
# 8406             Human Services
# 8407  Arts, Culture, Humanities
#
#                                             description  fscore  \
# 0     Working with Oregonians to enhance our quality...   88.61
# 1     Serving the metropolitan Baltimore area and th...   82.85
# 2     VSS Catholic Communications is dedicated to an...   86.74
# 3     The mission of the Utah Symphony & Opera is to...   91.03
# 4     Funded solely by the footwear industry, Two Te...   86.23
# ...                                                 ...     ...
# 8403  Founded in 1900, Yaddo is an artists' communit...   71.94
# ...

# %%
#How to save into a CSV file the current df.charity.drop, and adding the location, if you don´t want to add location just use - name_of_your_df.to_csv('file_name.csv',columns=['name'])
df_charity_data.to_csv(r'C:\Users\pauli\Desktop\Project\NCDF.csv',columns=["ascore","category","description","fscore","motto","name","score","state","subcategory","size"])

# %%
#Importinf file with the Top 10 best transparecy and financial score
dft_charity_data=pd.read_csv("top_charities.csv")

# %%
dft_charity_data
# Out:
#     Unnamed: 0  ascore  f score   \
# 0          1.0   100.0     100.0
# 1          2.0   100.0     100.0
# 2          3.0   100.0     100.0
# 3          4.0   100.0     100.0
# 4          5.0   100.0     100.0
# 5          6.0   100.0     100.0
# 6          7.0   100.0     100.0
# 7          8.0    97.0     100.0
# 8          9.0   100.0     100.0
# 9         10.0   100.0     100.0
# 10         NaN     NaN       NaN
# 11         NaN     NaN       NaN
# 12         NaN     NaN       NaN
# 13         NaN     NaN       NaN
# 14         NaN     NaN       NaN
# 15         NaN     NaN       NaN
# 16         NaN     NaN       NaN
# 17         NaN     NaN       NaN
# 18         NaN     NaN       NaN
# 19         NaN     NaN       NaN
#
#                                                  Name  \
# 0                               Nevada Humane Society
# 1                       United Way of Greater Houston
# 2                      Seeds of Hope Charitable Trust
# ...

# %%
#Arrange and save by filter categories for the project

# %%
df_charity_data=pd.read_csv("charity_data.csv")

# %%
df_charity_data.head()
columns_inter= ["ein","tot_exp","admin_exp_p","fund_eff","fund_exp_p","program_exp_p","leader","leader_comp","leader_comp_p","tot_rev","program_exp","fund_exp","admin_exp"]
df_charity_data.drop(columns=columns_inter)
# Out:
#       ascore                   category  \
# 0      100.0                Environment
# 1       89.0  Arts, Culture, Humanities
# 2       70.0                   Religion
# 3       93.0  Arts, Culture, Humanities
# 4      100.0             Human Services
# ...      ...                        ...
# 8403    92.0  Arts, Culture, Humanities
# 8404    59.0                   Religion
# 8405   100.0             Human Services
# 8406   100.0             Human Services
# 8407   100.0  Arts, Culture, Humanities
#
#                                             description  fscore  \
# 0     Working with Oregonians to enhance our quality...   88.61
# 1     Serving the metropolitan Baltimore area and th...   82.85
# 2     VSS Catholic Communications is dedicated to an...   86.74
# 3     The mission of the Utah Symphony & Opera is to...   91.03
# 4     Funded solely by the footwear industry, Two Te...   86.23
# ...                                                 ...     ...
# ...

# %%
ndf_charity_data=pd.read_csv("clean_df_Charity.csv")

# %%
ndf_charity_data
# Out:
#       Unnamed: 0  ascore                   category  \
# 0              0   100.0                Environment
# 1              1    89.0  Arts, Culture, Humanities
# 2              2    70.0                   Religion
# 3              3    93.0  Arts, Culture, Humanities
# 4              4   100.0             Human Services
# ...          ...     ...                        ...
# 8403        8403    92.0  Arts, Culture, Humanities
# 8404        8404    59.0                   Religion
# 8405        8405   100.0             Human Services
# 8406        8406   100.0             Human Services
# 8407        8407   100.0  Arts, Culture, Humanities
#
#                                             description  fscore  \
# 0     Working with Oregonians to enhance our quality...   88.61
# 1     Serving the metropolitan Baltimore area and th...   82.85
# 2     VSS Catholic Communications is dedicated to an...   86.74
# 3     The mission of the Utah Symphony & Opera is to...   91.03
# ...

# %%
filt = ndf_charity_data ['category'] == 'Animals'
series_filt = ndf_charity_data.loc[filt] 
series_filt.nlargest(10, 'ascore')
# Out:
#      Unnamed: 0  ascore category  \
# 19           19   100.0  Animals
# 34           34   100.0  Animals
# 77           77   100.0  Animals
# 82           82   100.0  Animals
# 106         106   100.0  Animals
# 247         247   100.0  Animals
# 498         498   100.0  Animals
# 578         578   100.0  Animals
# 581         581   100.0  Animals
# 603         603   100.0  Animals
#
#                                            description  fscore  \
# 19   Zoo Miami Foundation (ZMF) is the non-profit s...   91.15
# 34   The Israel Guide Dog Center for the Blind bega...  100.00
# 77   Founded in 1989, the International Rhino Found...   91.46
# 82   The International Primate Protection League (I...   96.11
# 106  The International Crane Foundation (ICF), foun...   88.65
# 247  The mission of the Idaho Humane Society is to ...   94.60
# 498  The Jacksonville Humane Society (JHS), establi...   82.38
# 578  The Kentucky Horse Park Foundation utilizes th...   57.50
# ...

# %%
filt = ndf_charity_data ['category'] == 'Animals'
series_filt.nlargest(10, 'ascore')



csv=series_filt.to_csv(r'C:\Users\pauli\Desktop\Project\animals.csv')
js = series_filt.to_json (r"C:\Users\pauli\Desktop\Project\animals.json", orient="columns")

# %%
filt = ndf_charity_data ['category'] == 'Arts, Culture, Humanities'
series_filt = ndf_charity_data.loc[filt] 
series_filt.nlargest(10, 'ascore')
# Out:
#      Unnamed: 0  ascore                   category  \
# 62           62   100.0  Arts, Culture, Humanities
# 235         235   100.0  Arts, Culture, Humanities
# 592         592   100.0  Arts, Culture, Humanities
# 609         609   100.0  Arts, Culture, Humanities
# 883         883   100.0  Arts, Culture, Humanities
# 917         917   100.0  Arts, Culture, Humanities
# 925         925   100.0  Arts, Culture, Humanities
# 932         932   100.0  Arts, Culture, Humanities
# 934         934   100.0  Arts, Culture, Humanities
# 956         956   100.0  Arts, Culture, Humanities
#
#                                            description  fscore  \
# 62   The mission of the Intrepid Sea, Air & Space M...   81.63
# 235  The mission of Imagine Children's Museum is to...   94.45
# 592  KCBX is a cultural resource which exists to en...   81.25
# 609  Founded in 1957, Kansas City Ballet is a 28-me...   93.27
# 883  Lake Erie Nature & Science Center educates and...   89.02
# ...

# %%
filt = ndf_charity_data ['category'] == 'Community Development'
series_filt = ndf_charity_data.loc[filt] 
series_filt.nlargest(10, 'ascore')
# Out:
#      Unnamed: 0  ascore               category  \
# 39           39   100.0  Community Development
# 52           52   100.0  Community Development
# 348         348   100.0  Community Development
# 353         353   100.0  Community Development
# 375         375   100.0  Community Development
# 378         378   100.0  Community Development
# 379         379   100.0  Community Development
# 390         390   100.0  Community Development
# 401         401   100.0  Community Development
# 407         407   100.0  Community Development
#
#                                            description  fscore  \
# 39   The Island Institute works to sustain Maine's ...   70.15
# 52   The Iranian American Jewish Federation of New ...   97.50
# 348  The Jewish United Fund of Metropolitan Chicago...   86.71
# 353  In 1926, Jewish National Fund was incorporated...   92.86
# 375  Jewish Federation & Foundation of Rockland Cou...   90.23
# ...

# %%
filt = ndf_charity_data ['category'] == 'Environment'
series_filt = ndf_charity_data.loc[filt] 
series_filt.nlargest(10, 'ascore')
# Out:
#       Unnamed: 0  ascore     category  \
# 0              0   100.0  Environment
# 14            14   100.0  Environment
# 38            38   100.0  Environment
# 45            45   100.0  Environment
# 160          160   100.0  Environment
# 714          714   100.0  Environment
# 759          759   100.0  Environment
# 829          829   100.0  Environment
# 967          967   100.0  Environment
# 1020        1020   100.0  Environment
#
#                                             description  fscore  \
# 0     Working with Oregonians to enhance our quality...   88.61
# 14    The Izaak Walton League of America was formed ...   79.94
# 38    Since 1984, Island Press has been publishing t...   84.83
# 45    Irvine is an environmental education organizat...   86.93
# 160   Founded in 1985, the Institute for Transportat...   82.50
# 714   Founded in 1998, Living Lands and Waters works...   89.30
# 759                  LightHawk flies to save the earth.   79.27
# ...
